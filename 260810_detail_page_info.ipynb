# %% [markdown]
# # 상세페이지 조회

# %% [markdown]
# ### 라이브러리 임포트

# %%
import requests
from bs4 import BeautifulSoup
from openpyxl import Workbook
import sys

print(sys.executable)
# Out:
# c:\vscode\crawlling\.venv\Scripts\python.exe

# %%
url = "https://cine21.com/movie/info/?movie_id=63091"

header = {
    "User-Agent": "Mozilla/5.0 (compatible; EducationalScraper/1.0; +https://example.com)"
}
response = requests.get(url, headers = header)

print("상태코드 : ", response.status_code)
# Out:
# 상태코드 :  200

# %%
html = response.text
soup = BeautifulSoup(html, "html.parser")

# %%
# 개봉일 / 등급 / 시간 / 누적 관객수 / 장르 / 국가 정보
info_list = []
items = soup.select("section.wide_dark_bg_wrap ul.info_list li p.title")
for i in items:
    n = i.next_sibling
    info = n.get_text(strip=True)
    info_list.append(info)

print(info_list)
# Out:
# ['2026-07-29', '12세이상관람가', '144분', '5,910,553명', '판타지, 어드벤처, 액션', '미국', '2026-07-29', '', '']

# %%
# 영화 감독 / 출연진
info_list2 = []
items = soup.select("section.wide_dark_bg_wrap ul.info_list a")
for i in items:
    info = i.get_text(strip=True)
    info_list2.append(info)

print(info_list2)
# Out:
# ['데스틴 크리튼', '톰 홀랜드', '젠데이아 콜먼', '세이디 싱크']

# %%
# 영화 아이디 리스트
movie_id_list = [63091, 62585, 63075, 62480, 63032, 62799, 63282, 62818, 63108, 63240]

# %%
#for d in movie_id_list:
    #url = f'https://cine21.com/movie/info/?movie_id={d}'
    #response = requests.get(url, headers = header)
    #html = response.text
    #soup = BeautifulSoup(html, "html.parser")
    #items = soup.select("section.wide_dark_bg_wrap ul.info_list li p.title")
    #items2 = soup.select("section.wide_dark_bg_wrap ul.info_list a")
    #for i in items:
        #n = i.next_sibling
        #info = n.get_text(strip=True)
        #info_list.append(info)
    #for i in items2:
        #info2 = i.get_text(strip=True)
        #info_list2.append(info2)

# %%
info_list = []
temp_list = []
info_list2 = []

for d in movie_id_list:
    url = f'https://cine21.com/movie/info/?movie_id={d}'
    response = requests.get(url, headers = header)
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    items = soup.select("section.wide_dark_bg_wrap ul.info_list li p.title")
    temp_list = []
    for i in items:
        n = i.next_sibling
        info = n.get_text(strip=True)
        temp_list.append(info)

    info_list.append(temp_list)


print(info_list)
# Out:
# [['2026-07-29', '12세이상관람가', '144분', '5,910,553명', '판타지, 어드벤처, 액션', '미국', '2026-07-29', '', ''], ['2026-08-05', '15세이상관람가', '172분', '1,872,877명', '액션, 모험, 드라마', '미국', '2026-08-05', '', ''], ['2026-08-05', '전체 관람가', '105분', '433,565명', '애니메이션', '한국', '2026-08-05', '', ''], ['2026-07-15', '15세이상관람가', '156분', '4,393,518명', '액션, 스릴러, SF', '한국', '2026-07-15', '', ''], ['2026-07-15', '전체 관람가', '89분', '763,404명', '애니메이션', '미국', '2026-07-15', '', ''], ['2026-06-17', '전체 관람가', '101분', '2,938,990명', '애니메이션', '미국', '2026-06-17', '', ''], ['2026-07-29', '12세이상관람가', '101분', '49,713명', '다큐멘터리', '일본', '2026-07-29', ''], ['2026-07-08', '전체 관람가', '115분', '1,020,487명', '어드벤처, 액션', '미국', '2026-07-08', '', ''], ['2026-07-10', '전체 관람가', '109분', '289,372명', '애니메이션', '미국', '2026-07-10', '', ''], ['2026-08-12', '15세이상관람가', '108분', '11,793명', '코미디', '한국', '2026-08-12', '', '']]

# %%
release_dates = []
movie_ratings = []
running_times = []
cumulative_viewers = []
movie_genres = []
release_countries =[]

for i in range(0, 9):
    date = info_list[i][0]
    release_dates.append(date)
    rating = info_list[i][1]
    movie_ratings.append(rating)
    running_time = info_list[i][2]
    running_times.append(running_time)
    cumulative_viewer = info_list[i][3]
    cumulative_viewers.append(cumulative_viewer)
    genre = info_list[i][4]
    movie_genres.append(genre)
    country = info_list[i][5]  
    release_countries.append(country)

# %%
print(release_dates)
print(movie_ratings)
# Out:
# ['2026-07-29', '2026-08-05', '2026-08-05', '2026-07-15', '2026-07-15', '2026-06-17', '2026-07-29', '2026-07-08', '2026-07-10']
# ['12세이상관람가', '15세이상관람가', '전체 관람가', '15세이상관람가', '전체 관람가', '전체 관람가', '12세이상관람가', '전체 관람가', '전체 관람가']

# %%
info_list2 = []

for d in movie_id_list:
    url = f'https://cine21.com/movie/info/?movie_id={d}'
    response = requests.get(url, headers = header)
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    items = soup.select("section.wide_dark_bg_wrap ul.info_list a")
    temp2_list = []
    for i in items:
        info = i.get_text(strip=True)
        temp2_list.append(info)
    
    info_list2.append(temp2_list)

print(info_list2)
# Out:
# [['데스틴 크리튼', '톰 홀랜드', '젠데이아 콜먼', '세이디 싱크'], ['크리스토퍼 놀란', '맷 데이먼', '톰 홀랜드', '앤 해서웨이'], ['김수훈', '이지현', '조경이'], ['나홍진', '황정민', '조인성', '정호연'], ['피에르 코팽', '트레이 파커', '앨리슨 제니'], ['앤드류 스탠튼', '맥케나 해리스', '톰 행크스', '팀 알렌', '조안 쿠삭'], ['후지노 토모아키'], ['토마스 케일', '드웨인 존슨', '캐서린 라가이아', '프랭키 애덤스'], ['필 커닝햄', '브렌트 도스', '박보검', '장광', '차지연'], ['이철하', '엄정화', '박성웅', '이상윤']]

# %%
movie_directors = []

for k in range(0, 9):
    director = info_list2[k][0]
    movie_directors.append(director)

print(movie_directors)
# Out:
# ['데스틴 크리튼', '크리스토퍼 놀란', '김수훈', '나홍진', '피에르 코팽', '앤드류 스탠튼', '후지노 토모아키', '토마스 케일', '필 커닝햄']

# %%
expert_evaluations = []

for id in movie_id_list:
    url = f'https://cine21.com/movie/info/?movie_id={id}'
    response = requests.get(url, headers = header)
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    items = soup.select("section.expert_star div.reviewer p")
    temp_list3 = []
    for i in items:
        num = i.get_text()
        temp_list3.append(num)
    expert_evaluations.append(temp_list3)

print(expert_evaluations)
# Out:
# [['송경원', '7', '정재현', '7', '이자연', '7', '이우빈', '7', '박평식', '7', '이주현', '9', '이용철', '7', '유선아', '7', '김현수', '8'], ['이자연', '8', '송경원', '8', '조현나', '7', '정재현', '7', '이우빈', '6', '박평식', '7', '최선', '9', '이주현', '9', '이용철', '8', '유선아', '7', '오진우', '7'], ['이자연', '7'], ['이우빈', '8', '김소미', '7', '박평식', '6', '유선아', '7', '이용철', '5', '오진우', '8'], ['최선', '6', '이용철', '7'], ['조현나', '7', '정재현', '6', '이자연', '8', '이우빈', '7', '박평식', '6', '이용철', '7'], ['송경원', '7', '남선우', '6', '이용철', '6', '이다혜', '7'], ['박평식', '5', '최선', '7', '이용철', '5'], ['최선', '5'], ['박평식', '5', '유선아', '4', '최선', '6']]

# %%
expert_reviews = []

for id in movie_id_list:
    url = f'https://cine21.com/movie/info/?movie_id={id}'
    response = requests.get(url, headers = header)
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    items = soup.select("section.expert_star div.review")
